# %%
from datasets import load_dataset

import pandas as pd

# %%
dataset = load_dataset("ai4privacy/pii-masking-200k/blob/main/german_pii_52k", data_files=["*.jsonl"])

# https://huggingface.co/datasets/ai4privacy/pii-masking-200k/blob/main/german_pii_52k.jsonl
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\I552412\GitHub\nlp_project\import_dataset.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/I552412/GitHub/nlp_project/import_dataset.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> dataset = load_dataset("ai4privacy/pii-masking-200k/blob/main/german_pii_52k", data_files=["*.jsonl"])
#       <a href='vscode-notebook-cell:/c%3A/Users/I552412/GitHub/nlp_project/import_dataset.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> # https://huggingface.co/datasets/ai4privacy/pii-masking-200k/blob/main/german_pii_52k.jsonl
#
# ...

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['masked_text', 'unmasked_text', 'privacy_mask', 'span_labels', 'bio_labels', 'tokenised_text'],
#         num_rows: 209261
#     })
# })

# %%
dataset["train"]
# Out:
# Dataset({
#     features: ['masked_text', 'unmasked_text', 'privacy_mask', 'span_labels', 'bio_labels', 'tokenised_text'],
#     num_rows: 209261
# })

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dataset["train"]["masked_text"]
# Out:
# ["A student's assessment was found on device bearing IMEI: [PHONEIMEI_1]. The document falls under the various topics discussed in our [JOBAREA_1] curriculum. Can you please collect it?",
#  "Dear [FIRSTNAME_1], as per our records, your license [VEHICLEVIN_1] is still registered in our records for access to the educational tools. Please feedback on it's operability.",
#  '[FIRSTNAME_1] could you please share your recomndations about vegetarian diet for [AGE_1] old [GENDER_1] with [HEIGHT_1]?',
#  'Emergency supplies in [BUILDINGNUMBER_1] need a refill. Use [MASKEDNUMBER_1] to pay for them.',
#  'The [AGE_1] old child at [BUILDINGNUMBER_1], has showcased an unusual ability to remember and recite passwords, with [PASSWORD_1] being most repeated.',
#  'Your recent hospital data recorded on [DOB_1] regarding chronic disease management has been encrypted with IPv6 [IPV6_1] for enhanced privacy.',
# ...

# %%
df = pd.DataFrame(dataset["train"])

# %%
df.to_csv("data/pii-masking-200k.csv")
